# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.proportion import proportions_chisquare

# %%
cancer=pd.read_excel('C:/Users/valer/Downloads/CancerCombinedFile.xlsx')
cancer
# Out:
#       Cancer_id            Name                 Category State_name  \
# 0         20010             Lip  Oral Cavity and Pharynx    Alabama
# 1         20010             Lip  Oral Cavity and Pharynx    Alabama
# 2         20010             Lip  Oral Cavity and Pharynx    Alabama
# 3         20010             Lip  Oral Cavity and Pharynx    Alabama
# 4         20020          Tongue  Oral Cavity and Pharynx    Alabama
# ...         ...             ...                      ...        ...
# 9914      36020  Kaposi Sarcoma           Kaposi Sarcoma    Wyoming
# 9915      36020  Kaposi Sarcoma           Kaposi Sarcoma    Wyoming
# 9916      37000   Miscellaneous            Miscellaneous    Wyoming
# 9917      37000   Miscellaneous            Miscellaneous    Wyoming
# 9918      37000   Miscellaneous            Miscellaneous    Wyoming
#
#                              Race_name  Count  \
# 0     American Indian or Alaska Native      0
# 1            Asian or Pacific Islander      0
# ...

# %%
cancer.drop(['Name','Cancer_id','Category','Count','Percentage population insured'], axis=1)
# Out:
#      State_name                         Race_name  \
# 0       Alabama  American Indian or Alaska Native
# 1       Alabama         Asian or Pacific Islander
# 2       Alabama                             White
# 3       Alabama  Other Races and Unknown combined
# 4       Alabama  American Indian or Alaska Native
# ...         ...                               ...
# 9914    Wyoming                             White
# 9915    Wyoming  Other Races and Unknown combined
# 9916    Wyoming         Asian or Pacific Islander
# 9917    Wyoming                             White
# 9918    Wyoming  Other Races and Unknown combined
#
#       Percentage population below poverty  Population
# 0                                    18.4     4874747
# 1                                    18.4     4874747
# 2                                    18.4     4874747
# 3                                    18.4     4874747
# 4                                    18.4     4874747
# ...

# %%
cancer.to_excel('C:/Users/valer/OneDrive/Documents/Final Project.xlsx')

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import openpyxl

# %%
cancer.to_excel('pandas_to_excel.xlsx', sheet_name='CancerProverty')

# %%
indexNames = cancer[ cancer['Cancer_id'] == 20010].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 37000].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 36020].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 36010].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 35041].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 35022].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 35021].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 35012].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 35011].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 34000].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 33041].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 33011].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 32020].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 32010].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 31040].index

# %%
indexNames = cancer[ cancer['Cancer_id'] == 31010].index
indexNames = cancer[ cancer['Cancer_id'] == 30000].index
indexNames = cancer[ cancer['Cancer_id'] == 29040].index
indexNames = cancer[ cancer['Cancer_id'] == 29030].index
indexNames = cancer[ cancer['Cancer_id'] == 29020].index
indexNames = cancer[ cancer['Cancer_id'] == 29010].index
indexNames = cancer[ cancer['Cancer_id'] == 28040].index
indexNames = cancer[ cancer['Cancer_id'] == 28030].index
indexNames = cancer[ cancer['Cancer_id'] == 28020].index
indexNames = cancer[ cancer['Cancer_id'] == 28010].index
indexNames = cancer[ cancer['Cancer_id'] == 26002].index
indexNames = cancer[ cancer['Cancer_id'] == 26001].index
indexNames = cancer[ cancer['Cancer_id'] == 25020].index
indexNames = cancer[ cancer['Cancer_id'] == 25010].index
indexNames = cancer[ cancer['Cancer_id'] == 24000].index
indexNames = cancer[ cancer['Cancer_id'] == 23000].index
indexNames = cancer[ cancer['Cancer_id'] == 22060].index
indexNames = cancer[ cancer['Cancer_id'] == 22050].index
indexNames = cancer[ cancer['Cancer_id'] == 22030].index
indexNames = cancer[ cancer['Cancer_id'] == 22020].index
indexNames = cancer[ cancer['Cancer_id'] == 22010].index
indexNames = cancer[ cancer['Cancer_id'] == 21130].index
indexNames = cancer[ cancer['Cancer_id'] == 21120].index
indexNames = cancer[ cancer['Cancer_id'] == 21110].index
indexNames = cancer[ cancer['Cancer_id'] == 21090].index
indexNames = cancer[ cancer['Cancer_id'] == 21080].index
indexNames = cancer[ cancer['Cancer_id'] == 21071].index
indexNames = cancer[ cancer['Cancer_id'] == 21060].index
indexNames = cancer[ cancer['Cancer_id'] == 21041].index
indexNames = cancer[ cancer['Cancer_id'] == 21030].index
indexNames = cancer[ cancer['Cancer_id'] == 21020].index
indexNames = cancer[ cancer['Cancer_id'] == 21010].index
indexNames = cancer[ cancer['Cancer_id'] == 20100].index
indexNames = cancer[ cancer['Cancer_id'] == 20090].index
indexNames = cancer[ cancer['Cancer_id'] == 20080].index
indexNames = cancer[ cancer['Cancer_id'] == 20070].index
indexNames = cancer[ cancer['Cancer_id'] == 20060].index
indexNames = cancer[ cancer['Cancer_id'] == 20050].index
indexNames = cancer[ cancer['Cancer_id'] == 20040].index
indexNames = cancer[ cancer['Cancer_id'] == 20030].index
indexNames = cancer[ cancer['Cancer_id'] == 20020].index

# %%
cancer.drop(indexNames , inplace=True)

# %%
cancer.head
# Out:
# <bound method NDFrame.head of       Cancer_id            Name                 Category State_name  \
# 0         20010             Lip  Oral Cavity and Pharynx    Alabama
# 1         20010             Lip  Oral Cavity and Pharynx    Alabama
# 2         20010             Lip  Oral Cavity and Pharynx    Alabama
# 3         20010             Lip  Oral Cavity and Pharynx    Alabama
# 7         20030  Salivary Gland  Oral Cavity and Pharynx    Alabama
# ...         ...             ...                      ...        ...
# 9914      36020  Kaposi Sarcoma           Kaposi Sarcoma    Wyoming
# 9915      36020  Kaposi Sarcoma           Kaposi Sarcoma    Wyoming
# 9916      37000   Miscellaneous            Miscellaneous    Wyoming
# 9917      37000   Miscellaneous            Miscellaneous    Wyoming
# 9918      37000   Miscellaneous            Miscellaneous    Wyoming
#
#                              Race_name  Count  \
# 0     American Indian or Alaska Native      0
# ...

# %%
cancer.drop( cancer[ cancer['Cancer_id'] == 20010 ].index , inplace=True)

# %%
cancer.head
# Out:
# <bound method NDFrame.head of       Cancer_id            Name                 Category State_name  \
# 7         20030  Salivary Gland  Oral Cavity and Pharynx    Alabama
# 8         20030  Salivary Gland  Oral Cavity and Pharynx    Alabama
# 9         20030  Salivary Gland  Oral Cavity and Pharynx    Alabama
# 10        20040  Floor of Mouth  Oral Cavity and Pharynx    Alabama
# 11        20040  Floor of Mouth  Oral Cavity and Pharynx    Alabama
# ...         ...             ...                      ...        ...
# 9914      36020  Kaposi Sarcoma           Kaposi Sarcoma    Wyoming
# 9915      36020  Kaposi Sarcoma           Kaposi Sarcoma    Wyoming
# 9916      37000   Miscellaneous            Miscellaneous    Wyoming
# 9917      37000   Miscellaneous            Miscellaneous    Wyoming
# 9918      37000   Miscellaneous            Miscellaneous    Wyoming
#
#                              Race_name  Count  \
# 7     American Indian or Alaska Native      0
# ...

# %%
cancer.drop( cancer[ cancer['Cancer_id'] == 20010].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 37000].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 36020].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 36010].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 35041].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 35022].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 35021].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 35012].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 35011].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 34000].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 33041].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 32020].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 32010].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 31040].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 31010].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 30000].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 29040].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 29030].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 29020].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 29010].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 28040].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 28020].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 28010].index , inplace=True) 
cancer.drop( cancer[ cancer['Cancer_id'] == 26002].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 26001].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 25020].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 25010].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 24000].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 23000].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 22060].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 22050].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 22030].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 22020].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 22010].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21130].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21120].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21110].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21090].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21080].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21071].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21060].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21041].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21030].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21020].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21010].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 20100].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 20090].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 20080].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 20070].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 20060].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 20050].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 20040].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 20030].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 20020].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 21100].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 33011].index , inplace=True)
cancer.drop( cancer[ cancer['Cancer_id'] == 28030].index , inplace=True)

# %%
cancer.head
# Out:
# <bound method NDFrame.head of       Cancer_id                         Name               Category  \
# 107       27010                 Cervix Uteri  Female Genital System
# 108       27010                 Cervix Uteri  Female Genital System
# 109       27010                 Cervix Uteri  Female Genital System
# 110       27020                 Corpus Uteri  Female Genital System
# 111       27020                 Corpus Uteri  Female Genital System
# ...         ...                          ...                    ...
# 9824      27060                        Vulva  Female Genital System
# 9825      27070  Other Female Genital Organs  Female Genital System
# 9826      27070  Other Female Genital Organs  Female Genital System
# 9827      27070  Other Female Genital Organs  Female Genital System
# 9828      27070  Other Female Genital Organs  Female Genital System
#
#      State_name                         Race_name  Count  \
# 107     Alabama  American Indian or Alaska Native      0
# ...

# %%
cancer.to_excel('cancerprovertyrace.xlsx', sheet_name='new_sheet_name')
